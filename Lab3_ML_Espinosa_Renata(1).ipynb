# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/envs/virtualenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import sys
sys.setrecursionlimit(1500)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt
#Since both datasets have continuous features you will implement decision trees that have binary splits. 
#For determining the optimal threshold for splitting you will need to search over all possible thresholds for
#a given feature (refer to class notes and discussion for an efficient search strategy). Use information gain to measure node impurity in your implementation.
#Growing Decision Trees
#Instead of growing full trees, you will use an early stopping strategy. To this end, wewill impose a limit on the minimum number 
#of instances at a leaf node, let thisthreshold be denoted as nmin, where nmin is described as a percentage relative to thesize 
#of the training dataset. For example, if the size of the training dataset is 150and nmin= 5, then a node will only be split further if it has more than eight instances.
#•For the Iris dataset use nmin E {5, 10, 15, 20}, and calculate the accuracy using10 fold cross-validation for each value of min.
#•For the Spambase dataset use nmin E {5, 10, 15, 20, 25}, and calculate theaccuracy using 10 fold cross-validation for each value of nmin.
#You can summarize your results in two separate tables, one for each dataset (report the average accuracy and standard deviation across the folds).

iris_df = pd.read_csv("iris.csv", names=["sepal_length", "sepal_width", "petal_length", "petal_width", "class"])
with pd.option_context('future.no_silent_downcasting', True):
    iris_df= iris_df.replace({'Iris-setosa':0, 'Iris-versicolor': 1, 'Iris-virginica': 2}).infer_objects()
X_iris = iris_df.drop(columns=["class"]).values  # All columns except "class"
y_iris = iris_df["class"].values 

spambase = pd.read_csv ("spambase.csv")
X_spam = spambase.iloc[:, :-1].values  # All columns except the last one
y_spam = spambase.iloc[:, -1].values   # Only the last column (target)

## Node Class
class TreeNode:
    def __init__(self, feature=None, threshold=None, left=None, right=None, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value
        self. predict_val= None
        self.leaf = False

# %%
## DecisionTree Class
#This class implements the entire decision tree algorithm.

class DecisionTree():
    """
    Training: Use "train" function with train set features and labels
    Predicting: Use "predict" function with test set features"""

    def __init__(self, min_samples_split, min_information_gain=0.0):
        self.min_samples_split = min_samples_split
        self.min_information_gain = min_information_gain
        self.root = None

    def entropy(self, y_1) -> float:
        counts = np.bincount(y_1)
        probabilities = counts / len(y_1)
        total_sum = 0
        for p in probabilities:
            if p > 0:
                total_sum += p * np.log2(p)
        result = -total_sum
        return result

    def information_gain(self, X_column, threshold, y_1):
        parent_entropy = self.entropy(y_1)
        left_mask = X_column <= threshold
        right_mask = X_column > threshold
        if np.sum(left_mask) == 0 or np.sum(right_mask) == 0:
            return 0
        left_entropy = self.entropy(y_1[left_mask])
        right_entropy = self.entropy(y_1[right_mask])
        n = len(y_1)
        n_left, n_right = len(y_1[left_mask]), len(y_1[right_mask])
        child_entropy = (n_left / n) * left_entropy + (n_right / n) * right_entropy
        return parent_entropy - child_entropy

    def best_split(self, X, y):
        best = -1
        split_id, split_threshold = None, None
        for feature_name in range(X.shape[1]):
            #get all values for each feature 
            X_column = X[:, feature_name]
            #determine all potential threholds
            thresholds = np.unique(X_column)
            # If there are fewer than 2 unique values, skip this feature
            if len(thresholds) < 2:
                continue
            # Calculate the average of every two adjacent unique sorted values
            thresholds1 = (thresholds[:-1] + thresholds[1:]) / 2
            for threshold in thresholds1:
                #calculate the gain to determine which one will it be the next feature
                gain = self.information_gain(X_column, threshold, y)
                if gain > best:
                    best = gain
                    split_id = feature_name
                    split_threshold = threshold
        return split_id, split_threshold  

    def most_occuring_label(self, y):
        label_counts = {}
        most_frequent_label = None
        max_count = -1
        # Count the occurrences of each label in y
        for label in y:
            if label in label_counts:
                label_counts[label] += 1
            else:
                label_counts[label] = 1
        # Find the label with the highest count
        for label1, count in label_counts.items():
            if count > max_count:
                max_count = count
                most_frequent_label = label1
        return most_frequent_label 

    def build_tree(self, X, y):
        percentage = X.shape[0] * self.min_samples_split/100
        if len(np.unique(y)) == 1 or (X.shape[0] < percentage):
            obj1=TreeNode(value=self.most_occuring_label(y))
            obj1.leaf = True
            return obj1
        best_feature, best_threshold = self.best_split(X, y)
        if best_feature is None:
            #print (best_feature)
            return TreeNode(value=self.most_occuring_label(y))
        left_side = X[:, best_feature] <= best_threshold
        right_side = X[:, best_feature] > best_threshold
        left_node = self.build_tree(X[left_side], y[left_side])
        right_node = self.build_tree(X[right_side], y[right_side])
        return TreeNode(feature=best_feature, threshold=best_threshold, left=left_node, right=right_node)

    def predict_one_row(self, node, row):
        if node.value is not None:
            return node.value
        if row[node.feature] <= node.threshold:
            return self.predict_one_row(node.left, row)
        return self.predict_one_row(node.right, row)

    def predict(self, X): 
        y_pred = [self.predict_one_row(self.root, row) for row in X]
        return np.array(y_pred)

# %%
def cross_validation_accuracy(tree, X, y):
    k=10
    kf = KFold(k, random_state=None, shuffle=True)
    accuracies = []
    for train, test in kf.split(X):
        X_train, X_test = X[train], X[test]
        y_train, y_test = y[train], y[test]
        tree.root = tree.build_tree(X_train, y_train)
        y_pred = tree.predict(X_test)
        accuracies.append(accuracy_score(y_test, y_pred))
    return np.mean(accuracies), np.std(accuracies)

#Running the code
n_min_values = [5, 10, 15, 20]
for n_min in n_min_values:
    tree = DecisionTree(min_samples_split=n_min)
    mean_acc, std_acc = cross_validation_accuracy(tree, X_iris, y_iris)
    print(f"Iris - n_min: {n_min}, Accuracy: {mean_acc:.3f}, Std: {std_acc:.3f}")
# Out:
# Iris - n_min: 5, Accuracy: 0.927, Std: 0.076
# Iris - n_min: 10, Accuracy: 0.960, Std: 0.033
# Iris - n_min: 15, Accuracy: 0.933, Std: 0.052
# Iris - n_min: 20, Accuracy: 0.940, Std: 0.055

# %%
def print_tree(node, depth=0):
    # If the node is a leaf, print the class label (value)
    if node.value is not None:
        print(f"{'|   ' * depth}Leaf: Class {node.value}")
    else:
        # Print the decision rule for the current node
        print(f"{'|   ' * depth}Feature {node.feature} <= {node.threshold:.2f}?")
        
        # Recursively print the left subtree
        print(f"{'|   ' * (depth + 1)}Left:")
        print_tree(node.left, depth + 1)
        
        # Recursively print the right subtree
        print(f"{'|   ' * (depth + 1)}Right:")
        print_tree(node.right, depth + 1)
# print_tree (tree.root)

# %%
n_min_values = [5, 10, 15, 20,25]
for n_min in n_min_values:
    print(f"Right Now running {n_min}")
    tree2 = DecisionTree(min_samples_split=n_min)
    print(f"Right Now running the cross validation {n_min}")
    mean_acc, std_acc = cross_validation_accuracy(tree2, X_spam, y_spam)
    print(f"Spam - n_min: {n_min}, Accuracy: {mean_acc:.3f}, Std: {std_acc:.3f}")
# Out:
# Right Now running 5
# Right Now running the cross validation 5
# Spam - n_min: 5, Accuracy: 0.922, Std: 0.011
# Right Now running 10
# Right Now running the cross validation 10
# Spam - n_min: 10, Accuracy: 0.925, Std: 0.010
# Right Now running 15
# Right Now running the cross validation 15
# Spam - n_min: 15, Accuracy: 0.926, Std: 0.009
# Right Now running 20
# Right Now running the cross validation 20
# Spam - n_min: 20, Accuracy: 0.923, Std: 0.012
# Right Now running 25
# Right Now running the cross validation 25
# Spam - n_min: 25, Accuracy: 0.927, Std: 0.009

# %%
print_tree (tree2.root)
# Out:
# Feature 51 <= 0.08?
# |   Left:
# |   Feature 6 <= 0.04?
# |   |   Left:
# |   |   Feature 52 <= 0.09?
# |   |   |   Left:
# |   |   |   Feature 24 <= 0.01?
# |   |   |   |   Left:
# |   |   |   |   Feature 55 <= 10.50?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 26 <= 0.12?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 15 <= 0.28?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 7 <= 0.14?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 54 <= 1.55?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 44 <= 0.78?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 18 <= 12.34?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 20 <= 0.61?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 19 <= 10.44?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.55?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.27?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.27?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 44 <= 0.76?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.07?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.04?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 4.30?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 4 <= 6.22?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 56 <= 6.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 56 <= 7.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 45 <= 1.56?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 4 <= 1.92?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 9 <= 2.17?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 41 <= 2.63?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 4 <= 8.01?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 5.15?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 17 <= 0.45?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 55 <= 5.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 20 <= 0.65?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 5.67?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 5.90?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 2 <= 0.25?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 6.40?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 9.37?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 20 <= 1.42?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 49 <= 0.13?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 5 <= 0.16?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 20 <= 4.53?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 2 <= 0.63?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 18 <= 1.07?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 2 <= 0.90?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 7 <= 8.49?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 20 <= 2.04?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 56 <= 113.00?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 15 <= 0.84?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 56 <= 30.00?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 15 <= 8.85?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 3.22?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 15 <= 0.91?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 11 <= 1.41?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 0 <= 0.35?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 4 <= 0.72?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 44 <= 0.35?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 26 <= 0.01?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 23 <= 0.01?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 36 <= 0.20?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 11 <= 1.56?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 55 <= 42.50?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 55 <= 26.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 53 <= 0.01?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 2.20?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 56 <= 65.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 16 <= 0.09?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 45 <= 0.70?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 11 <= 1.13?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 11 <= 0.40?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 3.67?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 4 <= 0.10?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 4.37?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 56 <= 34.00?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 56 <= 75.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 3.50?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 13 <= 2.77?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 8 <= 0.20?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 29 <= 0.06?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 9 <= 9.69?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 32 <= 1.51?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 55 <= 127.00?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 53 <= 0.63?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 49 <= 0.07?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 49 <= 0.13?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 45 <= 0.28?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 1 <= 0.20?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 11 <= 5.30?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 15 <= 0.28?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 5 <= 1.30?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 45 <= 0.26?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 17 <= 0.04?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 26 <= 0.35?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 4 <= 1.04?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 7 <= 0.11?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   Right:
# |   |   |   |   Feature 10 <= 0.99?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 56 <= 2429.50?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 25 <= 0.40?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 25 <= 0.39?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 48 <= 0.27?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 32 <= 0.99?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 32 <= 1.09?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 5 <= 0.03?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 0 <= 0.10?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 0 <= 0.04?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   Right:
# |   |   |   |   |   Leaf: Class 1
# |   |   |   Right:
# |   |   |   Feature 24 <= 0.24?
# |   |   |   |   Left:
# |   |   |   |   Feature 55 <= 9.50?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 17 <= 0.19?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 45 <= 0.45?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 54 <= 3.93?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 22 <= 0.07?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 4 <= 0.23?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 9 <= 0.10?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 54 <= 3.27?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 12 <= 3.68?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 48 <= 0.03?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 0 <= 0.18?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   Right:
# |   |   |   |   Leaf: Class 0
# |   |   Right:
# |   |   Feature 26 <= 0.08?
# |   |   |   Left:
# |   |   |   Feature 12 <= 0.04?
# |   |   |   |   Left:
# |   |   |   |   Feature 24 <= 0.15?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 7 <= 1.67?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 45 <= 0.14?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 55 <= 10.00?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 6 <= 0.91?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 13 <= 0.40?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 18 <= 5.13?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 6 <= 1.34?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 4 <= 3.12?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 25 <= 0.32?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 17 <= 0.97?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   Right:
# |   |   |   |   Leaf: Class 1
# |   |   |   Right:
# |   |   |   Leaf: Class 0
# |   Right:
# |   Feature 52 <= 0.01?
# |   |   Left:
# |   |   Feature 6 <= 0.06?
# |   |   |   Left:
# |   |   |   Feature 54 <= 2.75?
# |   |   |   |   Left:
# |   |   |   |   Feature 15 <= 0.41?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 16 <= 0.35?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 51 <= 0.76?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 20 <= 0.44?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 22 <= 1.29?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 54 <= 2.30?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 54 <= 2.30?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 2.35?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 49 <= 0.15?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 4 <= 0.20?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 18 <= 1.03?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 51 <= 0.30?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 26 <= 1.35?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.90?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 51 <= 0.33?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 36 <= 0.12?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 4 <= 1.29?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 1 <= 0.79?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 17 <= 0.55?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 55 <= 4.50?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 56 <= 2.50?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 44 <= 0.49?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 56 <= 6.50?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 55 <= 3.50?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 4.39?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 51 <= 1.55?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   Feature 18 <= 2.17?
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 18 <= 0.60?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 23 <= 2.08?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 44 <= 0.49?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 54 <= 1.97?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 51 <= 0.91?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 0 <= 0.14?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 5 <= 0.60?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 24 <= 0.20?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 51 <= 0.16?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 2 <= 0.39?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 51 <= 0.52?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 15 <= 1.33?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 18 <= 0.31?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 4 <= 0.13?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 4 <= 0.74?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 7 <= 0.27?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 56 <= 53.00?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 2 <= 0.72?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 56 <= 41.50?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 15 <= 1.00?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   Right:
# |   |   |   |   Feature 51 <= 0.50?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 20 <= 0.80?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 15 <= 0.91?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 50 <= 0.17?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 49 <= 0.10?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 20 <= 0.42?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 18 <= 0.25?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Feature 11 <= 1.28?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 2 <= 0.88?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 24 <= 0.10?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 4 <= 0.10?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 55 <= 50.00?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 11 <= 1.80?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 9 <= 0.49?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 44 <= 1.17?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 18 <= 1.40?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 56 <= 19.50?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 20 <= 1.37?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 8 <= 0.52?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Feature 8 <= 0.69?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 44 <= 1.41?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   Right:
# |   |   |   Feature 24 <= 0.23?
# |   |   |   |   Left:
# |   |   |   |   Feature 45 <= 0.12?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 29 <= 0.89?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 6 <= 2.81?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 6 <= 3.58?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 1 <= 0.33?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   Right:
# |   |   |   |   Leaf: Class 0
# |   |   Right:
# |   |   Feature 24 <= 0.61?
# |   |   |   Left:
# |   |   |   Feature 45 <= 0.20?
# |   |   |   |   Left:
# |   |   |   |   Feature 54 <= 2.51?
# |   |   |   |   |   Left:
# |   |   |   |   |   Feature 49 <= 0.05?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 54 <= 2.46?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 2 <= 0.42?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Feature 7 <= 0.40?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Feature 55 <= 27.50?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 6 <= 0.28?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 18 <= 3.30?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 52 <= 0.22?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Feature 8 <= 0.24?
# |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   Feature 12 <= 0.48?
# |   |   |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 1 <= 0.01?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Feature 55 <= 65.50?
# |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   Feature 17 <= 0.33?
# |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   Feature 41 <= 0.10?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 55 <= 66.50?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Feature 0 <= 0.15?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   Feature 52 <= 0.16?
# |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   Feature 55 <= 93.50?
# |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   Feature 15 <= 1.56?
# |   |   |   |   |   |   |   |   |   |   |   Left:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   |   |   |   Right:
# |   |   |   |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 1
# |   |   |   |   Right:
# |   |   |   |   Feature 20 <= 0.87?
# |   |   |   |   |   Left:
# |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   Right:
# |   |   |   |   |   Feature 2 <= 0.14?
# |   |   |   |   |   |   Left:
# |   |   |   |   |   |   Leaf: Class 0
# |   |   |   |   |   |   Right:
# |   |   |   |   |   |   Leaf: Class 1
# |   |   |   Right:
# |   |   |   Feature 6 <= 0.07?
# |   |   |   |   Left:
# |   |   |   |   Leaf: Class 0
# |   |   |   |   Right:
# |   |   |   |   Leaf: Class 1
